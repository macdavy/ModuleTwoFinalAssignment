# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# ## David Oyedele
# ## Data Scientist

# %% [markdown]
#  *I am interested in data science because I'd love to work with organizations to analyze their data and help give innovative ideas and solutions to both known and unknown problems to scale their firms, also I'd like to work with data to analyze human behaviour and psychology to better enhance living and human inter relationship.*

# %% [markdown]
# ### My below is code is supposed to multiply 10 by 10.

# %%
10 * 10
# Out:
# 100

# %% [markdown]
# ***
# ![IBM LOGO](https://upload.wikimedia.org/wikipedia/commons/f/fc/IBM_logo_in.jpg)
# [Link to IBM coursera website](https://www.coursera.org/professional-certificates/ibm-data-science)
# ---
